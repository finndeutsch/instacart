# %% [markdown]
# # 5 Grouping Data & Aggregating Variables

# %% [markdown]
# ## Table of contents
# 1. [Importing Libraries & Data](#imports)
# 2. [Aggregated mean of order number](#paragraph1)
# 3. [Loyalty flag](#paragraph2)
# 4. [Spending habits](#paragraph3)
# 5. [Types of spenders](#paragraph4)
# 6. [Frequent versus non-frequent customers](#paragraph5)
# 7. [Data export](#paragraph6)

# %% [markdown]
# ### 1. Importing Libraries & Data <a name="imports"></a>

# %%
# Importing pandas, numpy and os libraries
import pandas as pd
import numpy as np
import os

# %%
# Turning project folder path into a string
path = r'C:\Users\deuts\Desktop\Instacart Basket Analysis'

# Importing 'orders_products_merged_updated.pkl'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %% [markdown]
# ### 2. Aggregated mean of order number <a name="paragraph1"></a>

# %%
# Checking shape of the data frame
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
# Displaying average amount of orders per department
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})

# %%
# Caping a new data frame to 1000000 rows to compare to full data frame
df = ords_prods_merge[:1000000]

# %%
# Displaying average amount of orders per department for capped data frame
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# ##### The averages do not add up, since it's a larger data set now. The averages differ by up to 3 average orders.

# %% [markdown]
# ### 3. Loyalty flag <a name="paragraph2"></a>

# %%
# Displaying basic statistics for amount of orders per department
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
# Creating new column 'max_order'
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking output
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#     Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# 0          195         Soda        77              7     9.0   both
# 1          195         Soda        77              7     9.0   both
# 2          195         Soda        77              7     9.0   both
# 3          195         Soda        77              7     9.0   both
# 4          195         Soda        77              7     9.0   both
# 5          195         Soda        77              7     9.0   both
# 6          195         Soda        77              7     9.0   both
# 7          195         Soda        77              7     9.0   both
# 8          195         Soda        77              7     9.0   both
# 9          195         Soda        77              7     9.0   both
# 10         195         Soda        77              7     9.0   both
# 11         195         Soda        77              7     9.0   both
# 12         195         Soda        77              7     9.0   both
# 13         195         Soda        77              7     9.0   both
# 14         195         Soda        77              7     9.0   both
#
#       price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly busy        Average orders
# 1   Mid-range product  Regularly busy      Least busy        Average orders
# 2   Mid-range product  Regularly busy      Least busy           Most orders
# 3   Mid-range product      Least busy      Least busy        Average orders
# 4   Mid-range product      Least busy      Least busy           Most orders
# 5   Mid-range product  Regularly busy  Regularly busy        Average orders
# 6   Mid-range product  Regularly busy     Busiest day           Most orders
# 7   Mid-range product  Regularly busy     Busiest day           Most orders
# 8   Mid-range product  Regularly busy     Busiest day           Most orders
# 9   Mid-range product      Least busy      Least busy        Average orders
# 10  Mid-range product  Regularly busy     Busiest day           Most orders
# 11  Mid-range product  Regularly busy  Regularly busy           Most orders
# 12  Mid-range product  Regularly busy  Regularly busy           Most orders
# 13  Mid-range product  Regularly busy     Busiest day           Most orders
# 14  Mid-range product  Regularly busy     Busiest day           Most orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         22
# 11         22
# 12         22
# 13         22
# 14         22

# %%
# Creating loyalty flag for the whole df - 'Loyal customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Creating loyalty flag for the whole df - 'Regular customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Creating loyalty flag for the whole df - 'New customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Displaying output
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Checking result
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)

# %% [markdown]
# ### 4. Spending habits <a name="paragraph3"></a>

# %%
# Determining average, minumum and maximum of prices of products purchased by customer type
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# #### On average the New Customers spend the most in their orders, followed by regular and then loyal customers. The minimum with 1.0 and the maximum with 9999.0 spent is the same for alle Customer Types.

# %% [markdown]
# ### 5. Types of spenders <a name="paragraph4"></a>

# %%
# Creating new column 'average_spending' and displaying output
ords_prods_merge['average_spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
ords_prods_merge.head(15)

# %%
# Creating average_spending flag - 'Low spender'
ords_prods_merge.loc[ords_prods_merge['average_spending'] < 10, 'spending_flag'] = 'Low Spender'

# %%
# Creating loyalty flag - 'High spender '
ords_prods_merge.loc[(ords_prods_merge['average_spending'] >= 10), 'spending_flag'] = 'High Spender'

# %%
# Displaying output
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low Spender     31770614
# High Spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### 6. Frequent versus non-frequent customers <a name="paragraph5"></a>

# %%
# Creating new column 'average_spending' and displaying output
ords_prods_merge['purchase_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#     Unnamed: 0  ... _merge    price_range_loc     busiest_day    busiest_days  \
# 0          195  ...   both  Mid-range product  Regularly busy  Regularly busy
# 1          195  ...   both  Mid-range product  Regularly busy      Least busy
# 2          195  ...   both  Mid-range product  Regularly busy      Least busy
# 3          195  ...   both  Mid-range product      Least busy      Least busy
# 4          195  ...   both  Mid-range product      Least busy      Least busy
# 5          195  ...   both  Mid-range product  Regularly busy  Regularly busy
# 6          195  ...   both  Mid-range product  Regularly busy     Busiest day
# 7          195  ...   both  Mid-range product  Regularly busy     Busiest day
# 8          195  ...   both  Mid-range product  Regularly busy     Busiest day
# 9          195  ...   both  Mid-range product      Least busy      Least busy
# 10         195  ...   both  Mid-range product  Regularly busy     Busiest day
# 11         195  ...   both  Mid-range product  Regularly busy  Regularly busy
# 12         195  ...   both  Mid-range product  Regularly busy  Regularly busy
# 13         195  ...   both  Mid-range product  Regularly busy     Busiest day
# 14         195  ...   both  Mid-range product  Regularly busy     Busiest day
#
#    busiest_period_of_day max_order      loyalty_flag average_spending  \
# 0         Average orders        10      New customer         6.367797
# 1         Average orders        10      New customer         6.367797
# 2            Most orders        10      New customer         6.367797
# 3         Average orders        10      New customer         6.367797
# 4            Most orders        10      New customer         6.367797
# 5         Average orders        10      New customer         6.367797
# 6            Most orders        10      New customer         6.367797
# 7            Most orders        10      New customer         6.367797
# 8            Most orders        10      New customer         6.367797
# 9         Average orders        10      New customer         6.367797
# 10           Most orders        22  Regular customer         3.980556
# 11           Most orders        22  Regular customer         3.980556
# 12           Most orders        22  Regular customer         3.980556
# 13           Most orders        22  Regular customer         3.980556
# 14           Most orders        22  Regular customer         3.980556
#
#    spending_flag  purchase_frequency
# 0    Low Spender                20.5
# 1    Low Spender                20.5
# 2    Low Spender                20.5
# 3    Low Spender                20.5
# 4    Low Spender                20.5
# 5    Low Spender                20.5
# 6    Low Spender                20.5
# 7    Low Spender                20.5
# 8    Low Spender                20.5
# 9    Low Spender                20.5
# 10   Low Spender                10.0
# 11   Low Spender                10.0
# 12   Low Spender                10.0
# 13   Low Spender                10.0
# 14   Low Spender                10.0
#
# [15 rows x 24 columns]

# %%
# Creating frequency flag - 'Non-frequent customer'
ords_prods_merge.loc[ords_prods_merge['purchase_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
# Creating frequency flag - 'Regular customer'
ords_prods_merge.loc[(ords_prods_merge['purchase_frequency'] > 10) & (ords_prods_merge['purchase_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
# Creating frequency flag - 'Frequent customer'
ords_prods_merge.loc[(ords_prods_merge['purchase_frequency'] <= 10), 'frequency_flag'] = 'Frequent Customer'

# %%
# Displaying output
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent Customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %% [markdown]
# ### 7. Data export <a name="paragraph6"></a>

# %%
# Exporting data frame as pickle file to prepared data folder
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_final.pkl'))
